# %% [markdown]
# # Data visualization

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
at = np.load('./SWED_sample/train/images/S2A_MSIL2A_20170409T105651_N0204_R094_T30UYC_20170409T110529_image_0_0.npy')
al = np.load('./SWED_sample/train/labels/S2A_MSIL2A_20170409T105651_N0204_R094_T30UYC_20170409T110529_chip_0_0.npy')

# %%
#print(at.shape)
#print(at[0][0].shape)
temp = at[:,:,3:0:-1]
print(temp.shape)
temp = temp/10000
plt.imshow(temp)
# Out:
# (256, 256, 3)

# %%
#Printing Label Image

la = np.load('./SWED_sample/train/labels/S2A_MSIL2A_20170409T105651_N0204_R094_T30UYC_20170409T110529_chip_0_0.npy')

print(la[0].shape)

#Slicing
templ = la[0]

plt.imshow(templ,cmap='gray')
# Out:
# (256, 256)

# %%
import dataprep

# %%
X_train,Y_train = dataprep.DataPrep()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 X_train,Y_train = dataprep.DataPrep()
#
# File ~\workspace\CS291A-Computer_Vision\EdgeAttn-UNet\dataprep.py:20, in DataPrep(batch_size)
#      17 def DataPrep(batch_size=1):
#      18
#      19     #Getting into SWED_sample folder
# ---> 20     os.chdir('SWED_sample/')
#      22     #Entering each image and labels folder for training
#      23     image_path = os.path.join(os.getcwd(),"train/images/")
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'SWED_sample/'

# %%
from torch.utils.data import DataLoader

train_dataloader = DataLoader(X_train, batch_size=1, shuffle=False)
label_dataloader = DataLoader(Y_train, batch_size=1, shuffle=False)
