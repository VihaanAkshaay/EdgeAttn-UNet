# %% [markdown]
# # Data visualization

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
at = np.load('./SWED_sample/train/images/S2A_MSIL2A_20170409T105651_N0204_R094_T30UYC_20170409T110529_image_0_0.npy')

# %%
print(at.shape)
print(at[0][0].shape)
temp = at[0][0][1:3]

#Slicing
temp = np.zeros((256,256,3))

for i in range(256):
    for j in range(256):
        temp[i][j] = at[i][j][1:4]
print(temp.shape)
temp = temp * 0.001
print(temp)
plt.imshow(temp)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (256, 256, 12)
# (12,)
# (256, 256, 3)
# [[[0.472 0.801 0.373]
#   [0.375 0.759 0.317]
#   [0.351 0.685 0.279]
#   ...
#   [0.577 0.932 0.608]
#   [0.558 0.944 0.59 ]
#   [0.543 0.927 0.595]]
#
#  [[0.363 0.761 0.335]
#   [0.265 0.685 0.257]
#   [0.215 0.645 0.199]
#   ...
#   [0.467 0.885 0.581]
#   [0.454 0.893 0.566]
#   [0.459 0.846 0.507]]
#
#  [[0.358 0.734 0.318]
#   [0.294 0.655 0.233]
#   [0.21  0.662 0.192]
#   ...
#   [0.475 0.869 0.56 ]
#   [0.464 0.852 0.517]
#   [0.46  0.843 0.478]]
#
#  ...
#
#  [[0.428 0.65  0.44 ]
#   [0.257 0.459 0.308]
#   [0.354 0.554 0.355]
#   ...
#   [1.429 1.479 1.564]
#   [1.06  1.199 1.278]
#   [0.941 1.128 1.268]]
#
#  [[0.507 0.778 0.661]
#   [0.295 0.562 0.387]
#   [0.281 0.497 0.292]
#   ...
#   [1.401 1.515 1.684]
#   [1.229 1.425 1.626]
#   [1.205 1.633 1.861]]
#
#  [[0.711 0.99  1.02 ]
#   [0.395 0.708 0.487]
# ...

# %%
#Printing Label Image

la = np.load('./SWED_sample/train/labels/S2A_MSIL2A_20170409T105651_N0204_R094_T30UYC_20170409T110529_chip_0_0.npy')

print(la[0].shape)

#Slicing
templ = la[0]

plt.imshow(templ)
# Out:
# (256, 256)

# %%
templ = np.zeros((256,256))

for val in la[0]:
    if val == 1:
        print(val)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [35], in <cell line: 3>()
#       1 templ = np.zeros((256,256))
#       3 for val in la[0]:
# ----> 4     if val == 1:
#       5         print(val)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
